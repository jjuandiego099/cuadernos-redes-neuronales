# %%
pip install --upgrade git+https://github.com/aleju/imgaug.git
# Out:
# Collecting git+https://github.com/aleju/imgaug.git
#   Cloning https://github.com/aleju/imgaug.git to /tmp/pip-req-build-slr31m9r
#   Running command git clone --filter=blob:none --quiet https://github.com/aleju/imgaug.git /tmp/pip-req-build-slr31m9r
#   Resolved https://github.com/aleju/imgaug.git to commit 0101108d4fed06bc5056c4a03e2bcb0216dac326
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from imgaug==0.4.0) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.12/dist-packages (from imgaug==0.4.0) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from imgaug==0.4.0) (1.16.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from imgaug==0.4.0) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from imgaug==0.4.0) (3.10.0)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.12/dist-packages (from imgaug==0.4.0) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from imgaug==0.4.0) (4.13.0.92)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from imgaug==0.4.0) (2.37.3)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from imgaug==0.4.0) (2.1.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (3.6.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (2026.3.3)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (0.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug==0.4.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug==0.4.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug==0.4.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug==0.4.0) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug==0.4.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->imgaug==0.4.0) (2.9.0.post0)
# Building wheels for collected packages: imgaug
#   Building wheel for imgaug (setup.py) ... done
#   Created wheel for imgaug: filename=imgaug-0.4.0-py3-none-any.whl size=960979 sha256=5195d1b913da3bda951e6a08088c1cd8af7641fbbe98ddd4ce8df25d6fd604e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9nbe9ql7/wheels/3d/18/5f/20fc76b485bea8ed6398e419afe5b799cdd24e0a668ae83a45
# Successfully built imgaug
# Installing collected packages: imgaug
# Successfully installed imgaug-0.4.0

# %%
from keras import layers
import keras
import numpy as np
 
# Definir sctypes manualmente para engañar a librerías antiguas
if not hasattr(np, 'sctypes'):
    np.sctypes = {'int': [np.int8, np.int16, np.int32, np.int64],
                  'uint': [np.uint8, np.uint16, np.uint32, np.uint64],
                  'float': [np.float16, np.float32, np.float64],
                  'complex': [np.complex64, np.complex128],
                  'others': [bool, object, str, bytes]}
 
from imgaug.augmentables.kps import KeypointsOnImage, Keypoint
# OR more simply
from imgaug.augmentables import Keypoint, KeypointsOnImage
import imgaug.augmenters as iaa
 
 
from PIL import Image
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import pandas as pd
import json
import os

# %%
# !wget -q http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !tar xf images.tar
# !unzip -qq ~/downloads/stanfordextra_v12.zip
# Out:
# unzip:  cannot find or open /root/downloads/stanfordextra_v12.zip, /root/downloads/stanfordextra_v12.zip.zip or /root/downloads/stanfordextra_v12.zip.ZIP.
